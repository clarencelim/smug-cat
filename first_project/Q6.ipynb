# %% [markdown]
# ### Is there correlation between generation and strength (stats in general) of pokemon?
#
# Basically a question about power creep, does it exist in pokemon?
#
# Just my personal hypothesis on this, I would think generally in video game series power creep tends to always be a thing, given that increasing power levels is how you excite fans.
#
# But given pokemon's nature of wiping the slate clean with every release (releasing a whole new set of pokemon) this shouldn't really be an issue. We have seen emergence of 'Mega' pokemon and 'Primal' pokemon in our data set, so it would be unsurprising to find some mild power creep.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model

# %%
df = pd.read_csv('modified.csv')

# %%
df = df.drop(['Unnamed: 0'] , axis = 1)

# %%
df.to_csv('modified.csv', index = False)

# %%
df = pd.read_csv('modified.csv')

# %%
df = df.drop(['#'], axis = 1)

# %%
sns.heatmap(df.corr(), cmap = 'Greens' )

# %% [markdown]
# ### Closing Notes
#
# I initially wanted to do a linear regression model to answer this question, but found it some what unsuitable given the data characteristics involved. Instead, I found this correlation heatmap more suitable.
#
# If given the opportunity on another dataset I will definitely try regression isntead.
