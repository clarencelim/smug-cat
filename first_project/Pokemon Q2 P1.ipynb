# %%
import pandas as pd

# %%
pokemon = pd.read_csv('modified.csv')

# %%
df = pd.DataFrame(pokemon)

# %%
df.describe()
# Out:
#                 #       Total          HP      Attack     Defense     Sp. Atk  \
# count  751.000000  751.000000  751.000000  751.000000  751.000000  751.000000
# mean   369.723036  423.322237   68.669774   75.978695   71.744341   70.213049
# std    209.480412  112.932936   25.946152   29.920554   29.629870   30.263860
# min      1.000000  180.000000    1.000000    5.000000    5.000000   10.000000
# 25%    189.500000  325.000000   50.000000   55.000000   50.000000   45.000000
# 50%    377.000000  430.000000   65.000000   75.000000   68.000000   65.000000
# 75%    550.500000  500.000000   80.000000   95.000000   90.000000   90.000000
# max    721.000000  770.000000  255.000000  180.000000  230.000000  180.000000
#
#           Sp. Def       Speed  Generation    Strength
# count  751.000000  751.000000  751.000000  751.000000
# mean    70.109188   66.607190    3.380826  146.191744
# std     27.401096   27.845601    1.671360   49.947871
# ...

# %%
df['Type 2'].count()
# Out:
# 375

# %%
df.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary  Strength
# 0     45           1      False       114
# 1     60           1      False       142
# 2     80           1      False       182
# 3     65           1      False       112
# 4     80           1      False       144

# %%
#Strongest Fire vs Water, who will win? (Felicia)
#Now one would naturally assume because of elemental advantage, Water would win, but let us see.
#I shall now just take 'Total' stat as an indicator of Strength/Who will win

# %%
df = df.drop('Strength', axis = 1)

# %%
#before comparing individiuals, let's just look at Water vs Fire on a macro level

# %%
df.groupby(['Type 1']).sum().sort_values('Total', ascending = False)
#but sum doesn't really reveal much as we could simply have more Water than Fire pokeman.
# Out:
#               #  Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Water     33148  45156  7632    7682     7581     7839     7398   7024
# Normal    30187  37071  7217    6799     5465     5141     5843   6606
# Grass     23270  27106  4389    4701     4553     4943     4520   4000
# Bug       22512  23851  3645    4257     4465     3532     4096   3856
# Psychic   20584  23743  3623    3433     3463     4856     4353   4015
# Fire      16433  21362  3329    3894     3155     4063     3370   3551
# Electric  15503  18325  2471    2870     2732     3661     3053   3538
# Rock      16171  17950  2646    3627     4090     2462     2996   2129
# Ground    11401  14000  2361    3064     2715     1807     2008   2045
# Dragon    12883  13447  2123    2753     2089     2269     2183   2030
# Ghost     15120  12911  1938    2131     2443     2276     2269   1854
# Dark      13412  12173  1881    2415     1902     1974     1890   2111
# ...

# %%
water = df['Type 1'] == 'Water'
df[water].count()
# Out:
# #             107
# Name          107
# Type 1        107
# Type 2         49
# Total         107
# HP            107
# Attack        107
# Defense       107
# Sp. Atk       107
# Sp. Def       107
# Speed         107
# Generation    107
# Legendary     107
# dtype: int64

# %%
fire = df['Type 1'] == 'Fire'
df[fire].count()
# Out:
# #             48
# Name          48
# Type 1        48
# Type 2        20
# Total         48
# HP            48
# Attack        48
# Defense       48
# Sp. Atk       48
# Sp. Def       48
# Speed         48
# Generation    48
# Legendary     48
# dtype: int64

# %%
atype = df.groupby(['Type 1']).mean().sort_values('Total', ascending = False)
atype
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Dragon    495.500000  517.192308  81.653846  105.884615   80.346154
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Steel     468.000000  467.304348  64.608696   86.434783  116.391304
# Psychic   395.846154  456.596154  69.673077   66.019231   66.596154
# Fire      342.354167  445.041667  69.354167   81.125000   65.729167
# Rock      394.414634  437.804878  64.536585   88.463415   99.756098
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Electric  369.119048  436.309524  58.833333   68.333333   65.047619
# Dark      479.000000  434.750000  67.178571   86.250000   67.928571
# Ghost     504.000000  430.366667  64.600000   71.033333   81.433333
# Ice       426.217391  427.086957  71.652174   70.695652   71.043478
# Water     309.794393  422.018692  71.327103   71.794393   70.850467
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
# ...

# %%
#how much stronger are Fire types over Water?
atype.loc['Fire','Total'] - atype.loc['Water','Total']
# Out:
# 23.022975077881654

# %%
#instead of filtering a Fire DF and a Water type DF, I shall attempt to just compare and locate the pokemon in one block

# %%
filter = (df['Type 1'] == 'Water') | (df['Type 1'] == 'Fire')

# %%
df[filter]
#so I clearly fucked up something here, all Type 1 have been replcaed with water. so, time to restart
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Water  Poison    318   45      49       49
# 1      2                Ivysaur  Water  Poison    405   60      62       63
# 2      3               Venusaur  Water  Poison    525   80      82       83
# 3      4             Charmander  Water     NaN    309   39      52       43
# 4      5             Charmeleon  Water     NaN    405   58      64       58
# 5      6              Charizard  Water  Flying    534   78      84       78
# 6      7               Squirtle  Water     NaN    314   44      48       65
# 7      8              Wartortle  Water     NaN    405   59      63       80
# 8      9              Blastoise  Water     NaN    530   79      83      100
# 9     10               Caterpie  Water     NaN    195   45      30       35
# 10    11                Metapod  Water     NaN    205   50      20       55
# ...

# %%
list = []
for row in df:
    if 'Type 1 ' == 'Water':
        list.append(row)
    elif 'Type 1' == 'Fire':
        list.append(row)

# %%
list
# Out:
# []
